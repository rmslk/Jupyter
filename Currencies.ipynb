# %%
import requests
import xmltodict

url = "http://www.cbr.ru/scripts/XML_daily.asp"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="windows-1251"?><ValCurs Date="19.04.2022" name="Foreign Currency Market"><Valute ID="R01010"><NumCode>036</NumCode><CharCode>AUD</CharCode><Nominal>1</Nominal><Name>\xc0\xe2\xf1\xf2\xf0\xe0\xeb\xe8\xe9\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>59,2560</Value></Valute><Valute ID="R01020A"><NumCode>944</NumCode><CharCode>AZN</CharCode><Nominal>1</Nominal><Name>\xc0\xe7\xe5\xf0\xe1\xe0\xe9\xe4\xe6\xe0\xed\xf1\xea\xe8\xe9 \xec\xe0\xed\xe0\xf2</Name><Value>46,7370</Value></Valute><Valute ID="R01035"><NumCode>826</NumCode><CharCode>GBP</CharCode><Nominal>1</Nominal><Name>\xd4\xf3\xed\xf2 \xf1\xf2\xe5\xf0\xeb\xe8\xed\xe3\xee\xe2 \xd1\xee\xe5\xe4\xe8\xed\xe5\xed\xed\xee\xe3\xee \xea\xee\xf0\xee\xeb\xe5\xe2\xf1\xf2\xe2\xe0</Name><Value>103,5907</Value></Valute><Valute ID="R01060"><NumCode>051</NumCode><CharCode>AMD</CharCode><Nominal>100</Nominal><Name>\xc0\xf0\xec\xff\xed\xf1\xea\xe8\xf5 \xe4\xf0\xe0\xec\xee\xe2</Name><Value>16,8565</Value></Valute><Valute ID="R01090B"><NumCode>933</NumCode><CharCode>BYN</CharCode><Nominal>1</Nominal><Name>\xc1\xe5\xeb\xee\xf0\xf3\xf1\xf1\xea\xe8\xe9 \xf0\xf3\xe1\xeb\xfc</Name><Value>28,2821</Value></Valute><Valute ID="R01100"><NumCode>975</NumCode><CharCode>BGN</CharCode><Nominal>1</Nominal><Name>\xc1\xee\xeb\xe3\xe0\xf0\xf1\xea\xe8\xe9 \xeb\xe5\xe2</Name><Value>44,1896</Value></Valute><Valute ID="R01115"><NumCode>986</NumCode><CharCode>BRL</CharCode><Nominal>1</Nominal><Name>\xc1\xf0\xe0\xe7\xe8\xeb\xfc\xf1\xea\xe8\xe9 \xf0\xe5\xe0\xeb</Name><Value>16,8493</Value></Valute><Valute ID="R01135"><NumCode>348</NumCode><CharCode>HUF</CharCode><Nominal>100</Nominal><Name>\xc2\xe5\xed\xe3\xe5\xf0\xf1\xea\xe8\xf5 \xf4\xee\xf0\xe8\xed\xf2\xee\xe2</Name><Value>23,0452</Value></Valute><Valute ID="R01200"><NumCode>344</NumCode><CharCode>HKD</CharCode><Nominal>1</Nominal><Name>\xc3\xee\xed\xea\xee\xed\xe3\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>10,1485</Value></Valute><Valute ID="R01215"><NumCode>208</NumCode><CharCode>DKK</CharCode><Nominal>1</Nominal><Name>\xc4\xe0\xf2\xf1\xea\xe0\xff \xea\xf0\xee\xed\xe0</Name><Value>11,5649</Value></Valute><Valute ID="R01235"><NumCode>840</NumCode><CharCode>USD</CharCode><Nominal>1</Nominal><Name>\xc4\xee\xeb\xeb\xe0\xf0 \xd1\xd8\xc0</Name><Value>79,4529</Value></Valute><Valute ID="R01239"><NumCode>978</NumCode><CharCode>EUR</CharCode><Nominal>1</Nominal><Name>\xc5\xe2\xf0\xee</Name><Value>86,4289</Value></Valute><Valute ID="R01270"><NumCode>356</NumCode><CharCode>INR</CharCode><Nominal>10</Nominal><Name>\xc8\xed\xe4\xe8\xe9\xf1\xea\xe8\xf5 \xf0\xf3\xef\xe8\xe9</Name><Value>10,4595</Value></Valute><Valute ID="R01335"><NumCode>398</NumCode><CharCode>KZT</CharCode><Nominal>100</Nominal><Name>\xca\xe0\xe7\xe0\xf5\xf1\xf2\xe0\xed\xf1\xea\xe8\xf5 \xf2\xe5\xed\xe3\xe5</Name><Value>17,4902</Value></Valute><Valute ID="R01350"><NumCode>124</NumCode><CharCode>CAD</CharCode><Nominal>1</Nominal><Name>\xca\xe0\xed\xe0\xe4\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>63,0529</Value></Valute><Valute ID="R01370"><NumCode>417</NumCode><CharCode>KGS</CharCode><Nominal>100</Nominal><Name>\xca\xe8\xf0\xe3\xe8\xe7\xf1\xea\xe8\xf5 \xf1\xee\xec\xee\xe2</Name><Value>98,7637</Value></Valute><Valute ID="R01375"><NumCode>156</NumCode><CharCode>CNY</CharCode><Nominal>1</Nominal><Name>\xca\xe8\xf2\xe0\xe9\xf1\xea\xe8\xe9 \xfe\xe0\xed\xfc</Name><Value>12,4818</Value></Valute><Valute ID="R01500"><NumCode>498</NumCode><CharCode>MDL</CharCode><Nominal>10</Nominal><Name>\xcc\xee\xeb\xe4\xe0\xe2\xf1\xea\xe8\xf5 \xeb\xe5\xe5\xe2</Name><Value>43,0487</Value></Valute><Valute ID="R01535"><NumCode>578</NumCode><CharCode>NOK</CharCode><Nominal>10</Nominal><Name>\xcd\xee\xf0\xe2\xe5\xe6\xf1\xea\xe8\xf5 \xea\xf0\xee\xed</Name><Value>89,8870</Value></Valute><Valute ID="R01565"><NumCode>985</NumCode><CharCode>PLN</CharCode><Nominal>1</Nominal><Name>\xcf\xee\xeb\xfc\xf1\xea\xe8\xe9 \xe7\xeb\xee\xf2\xfb\xe9</Name><Value>18,5920</Value></Valute><Valute ID=" ...

# %%
data = xmltodict.parse(response.content)
data
# Out:
# OrderedDict([('ValCurs',
#               OrderedDict([('@Date', '19.04.2022'),
#                            ('@name', 'Foreign Currency Market'),
#                            ('Valute',
#                             [OrderedDict([('@ID', 'R01010'),
#                                           ('NumCode', '036'),
#                                           ('CharCode', 'AUD'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Австралийский доллар'),
#                                           ('Value', '59,2560')]),
#                              OrderedDict([('@ID', 'R01020A'),
#                                           ('NumCode', '944'),
#                                           ('CharCode', 'AZN'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Азербайджанский манат'),
#                                           ('Value', '46,7370')]),
#                              OrderedDict([('@ID', 'R01035'),
#                                           ('NumCode', '826'),
#                                           ('CharCode', 'GBP'),
#                                           ('Nominal', '1'),
#                                           ('Name',
#                                            'Фунт стерлингов Соединенного королевства'),
#                                           ('Value', '103,5907')]),
#                              OrderedDict([('@ID', 'R01060'),
#                                           ('NumCode', '051'),
#                                           ('CharCode', 'AMD'),
#                                           ('Nominal', '100'),
#                                           ('Name', 'Армянских драмов'),
#                                           ('Value', '16,8565')]),
#                              OrderedDict([('@ID', 'R01090B'),
#                                           ('NumCode', '933'),
#                                           ('CharCode', 'BYN'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Белорусский рубль'),
#                                           ('Value', '28,2821')]),
#                              OrderedDict([('@ID', 'R01100'),
#                                           ('NumCode', '975'),
#                                           ('CharCode', 'BGN'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Болгарский лев'),
#                                           ('Value', '44,1896')]),
#                              OrderedDict([('@ID', 'R01115'),
#                                           ('NumCode', '986'),
#                                           ('CharCode', 'BRL'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Бразильский реал'),
#                                           ('Value', '16,8493')]),
#                              OrderedDict([('@ID', 'R01135'),
#                                           ('NumCode', '348'),
#                                           ('CharCode', 'HUF'),
#                                           ('Nominal', '100'),
#                                           ('Name', 'Венгерских форинтов'),
#                                           ('Value', '23,0452')]),
#                              OrderedDict([('@ID', 'R01200'),
#                                           ('NumCode', '344'),
#                                           ('CharCode', 'HKD'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Гонконгский доллар'),
#                                           ('Value', '10,1485')]),
#                              OrderedDict([('@ID', 'R01215'),
#                                           ('NumCode', '208'),
#                                           ('CharCode', 'DKK'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Датская крона'),
#                                           ('Value', '11,5649')]),
#                              OrderedDict([('@ID', 'R01235'),
#                                           ('NumCode', '840'),
#                                           ('CharCode', 'USD'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Доллар США'),
#                                           ('Value', '79,4529')]),
#                              OrderedDict([('@ID', 'R01239'),
#                                           ('NumCode', '978'),
#                                           ('CharCode', 'EUR'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Евро'),
#                                           ('Value', '86,4289')]),
#                              OrderedDict([('@ID', 'R01270'),
#                                           ('NumCode', '356'),
#                                           ('CharCode', 'INR'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Индийских рупий'),
#                                           ('Value', '10,4595')]),
#                              OrderedDict([('@ID', 'R01335'),
#                                           ('NumCode', '398'),
#                                           ('CharCode', 'KZT'),
#                                           ('Nominal', '100'),
#                                           ('Name', 'Казахстанских тенге'),
#                                           ('Value', '17,4902')]),
#                              OrderedDict([('@ID', 'R01350'),
#                                           ('NumCode', '124'),
#                                           ('CharCode', 'CAD'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Канадский доллар'),
#                                           ('Value', '63,0529')]),
#                              OrderedDict([('@ID', 'R01370'),
#                                           ('NumCode', '417'),
#                                           ('CharCode', 'KGS'),
#                                           ('Nominal', '100'),
#                                           ('Name', 'Киргизских сомов'),
#                                           ('Value', '98,7637')]),
#                              OrderedDict([('@ID', 'R01375'),
#                                           ('NumCode', '156'),
#                                           ('CharCode', 'CNY'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Китайский юань'),
#                                           ('Value', '12,4818')]),
#                              OrderedDict([('@ID', 'R01500'),
#                                           ('NumCode', '498'),
#                                           ('CharCode', 'MDL'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Молдавских леев'),
#                                           ('Value', '43,0487')]),
#                              OrderedDict([('@ID', 'R01535'),
#                                           ('NumCode', '578'),
#                                           ('CharCode', 'NOK'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Норвежских крон'),
#                                           ('Value', '89,8870')]),
#                              OrderedDict([('@ID', 'R01565'),
#                                           ('NumCode', '985'),
#                                           ('CharCode', 'PLN'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Польский злотый'),
#                                           ('Value', '18,5920')]),
#                              OrderedDict([('@ID', 'R01585F'),
#                                           ('NumCode', '946'),
#                                           ('CharCode', 'RON'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Румынский лей'),
#                                           ('Value', '17,3520')]),
#                              OrderedDict([('@ID', 'R01589'),
#                                           ('NumCode', '960'),
#                                           ('CharCode', 'XDR'),
#                                           ('Nominal', '1'),
#                                           ('Name',
#                                            'СДР (специальные права заимствования)'),
#                                           ('Value', '108,5644')]),
#                              OrderedDict([('@ID', 'R01625'),
#                                           ('NumCode', '702'),
#                                           ('CharCode', 'SGD'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Сингапурский доллар'),
#                                           ('Value', '58,4470')]),
#                              OrderedDict([('@ID', 'R01670'),
#                                           ('NumCode', '972'),
#                                           ('CharCode', 'TJS'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Таджикских сомони'),
#                                           ('Value', '63,5242')]),
#                              OrderedDict([('@ID', 'R01700J'),
#                                           ('NumCode', '949'),
#                                           ('CharCode', 'TRY'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Турецких лир'),
#                                           ('Value', '54,2774')]),
#                              OrderedDict([('@ID', 'R01710A'),
#                                           ('NumCode', '934'),
#                                           ('CharCode', 'TMT'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Новый туркменский манат'),
#                                           ('Value', '22,7008')]),
#                              OrderedDict([('@ID', 'R01717'),
#                                           ('NumCode', '860'),
#                                           ('CharCode', 'UZS'),
#                                           ('Nominal', '10000'),
#                                           ('Name', 'Узбекских сумов'),
#                                           ('Value', '70,3159')]),
#                              OrderedDict([('@ID', 'R01720'),
#                                           ('NumCode', '980'),
#                                           ('CharCode', 'UAH'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Украинских гривен'),
#                                           ('Value', '26,9005')]),
#                              OrderedDict([('@ID', 'R01760'),
#                                           ('NumCode', '203'),
#                                           ('CharCode', 'CZK'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Чешских крон'),
#                                           ('Value', '35,3895')]),
#                              OrderedDict([('@ID', 'R01770'),
#                                           ('NumCode', '752'),
#                                           ('CharCode', 'SEK'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Шведских крон'),
#                                           ('Value', '84,1404')]),
#                              OrderedDict([('@ID', 'R01775'),
#                                           ('NumCode', '756'),
#                                           ('CharCode', 'CHF'),
#                                           ('Nominal', '1'),
#                                           ('Name', 'Швейцарский франк'),
#                                           ('Value', '84,9764')]),
#                              OrderedDict([('@ID', 'R01810'),
#                                           ('NumCode', '710'),
#                                           ('CharCode', 'ZAR'),
#                                           ('Nominal', '10'),
#                                           ('Name', 'Южноафриканских рэндов'),
#                                           ('Value', '54,2404')]),
#                              OrderedDict([('@ID', 'R01815'),
#                                           ('NumCode', '410'),
#                                           ('CharCode', 'KRW'),
#                                           ('Nominal', '1000'),
#                                           ('Name', 'Вон Республики Корея'),
#                                           ('Value', '64,3656')]),
#                              OrderedDict([('@ID', 'R01820'),
#                                           ('NumCode', '392'),
#                                           ('CharCode', 'JPY'),
#                                           ('Nominal', '100'),
#                                           ('Name', 'Японских иен'),
#                                           ('Value', '62,7392')])])]))])

# %%
items = []
for item in data['ValCurs']['Valute']:
    items.append(item)
items
# Out:
# [OrderedDict([('@ID', 'R01010'),
#               ('NumCode', '036'),
#               ('CharCode', 'AUD'),
#               ('Nominal', '1'),
#               ('Name', 'Австралийский доллар'),
#               ('Value', '59,2560')]),
#  OrderedDict([('@ID', 'R01020A'),
#               ('NumCode', '944'),
#               ('CharCode', 'AZN'),
#               ('Nominal', '1'),
#               ('Name', 'Азербайджанский манат'),
#               ('Value', '46,7370')]),
#  OrderedDict([('@ID', 'R01035'),
#               ('NumCode', '826'),
#               ('CharCode', 'GBP'),
#               ('Nominal', '1'),
#               ('Name', 'Фунт стерлингов Соединенного королевства'),
#               ('Value', '103,5907')]),
#  OrderedDict([('@ID', 'R01060'),
#               ('NumCode', '051'),
#               ('CharCode', 'AMD'),
#               ('Nominal', '100'),
#               ('Name', 'Армянских драмов'),
#               ('Value', '16,8565')]),
#  OrderedDict([('@ID', 'R01090B'),
#               ('NumCode', '933'),
#               ('CharCode', 'BYN'),
#               ('Nominal', '1'),
#               ('Name', 'Белорусский рубль'),
#               ('Value', '28,2821')]),
#  OrderedDict([('@ID', 'R01100'),
#               ('NumCode', '975'),
#               ('CharCode', 'BGN'),
#               ('Nominal', '1'),
#               ('Name', 'Болгарский лев'),
#               ('Value', '44,1896')]),
#  OrderedDict([('@ID', 'R01115'),
#               ('NumCode', '986'),
#               ('CharCode', 'BRL'),
#               ('Nominal', '1'),
#               ('Name', 'Бразильский реал'),
#               ('Value', '16,8493')]),
#  OrderedDict([('@ID', 'R01135'),
#               ('NumCode', '348'),
#               ('CharCode', 'HUF'),
#               ('Nominal', '100'),
#               ('Name', 'Венгерских форинтов'),
#               ('Value', '23,0452')]),
#  OrderedDict([('@ID', 'R01200'),
#               ('NumCode', '344'),
#               ('CharCode', 'HKD'),
#               ('Nominal', '1'),
#               ('Name', 'Гонконгский доллар'),
#               ('Value', '10,1485')]),
#  OrderedDict([('@ID', 'R01215'),
#               ('NumCode', '208'),
#               ('CharCode', 'DKK'),
#               ('Nominal', '1'),
#               ('Name', 'Датская крона'),
#               ('Value', '11,5649')]),
#  OrderedDict([('@ID', 'R01235'),
#               ('NumCode', '840'),
#               ('CharCode', 'USD'),
#               ('Nominal', '1'),
#               ('Name', 'Доллар США'),
#               ('Value', '79,4529')]),
#  OrderedDict([('@ID', 'R01239'),
#               ('NumCode', '978'),
#               ('CharCode', 'EUR'),
#               ('Nominal', '1'),
#               ('Name', 'Евро'),
#               ('Value', '86,4289')]),
#  OrderedDict([('@ID', 'R01270'),
#               ('NumCode', '356'),
#               ('CharCode', 'INR'),
#               ('Nominal', '10'),
#               ('Name', 'Индийских рупий'),
#               ('Value', '10,4595')]),
#  OrderedDict([('@ID', 'R01335'),
#               ('NumCode', '398'),
#               ('CharCode', 'KZT'),
#               ('Nominal', '100'),
#               ('Name', 'Казахстанских тенге'),
#               ('Value', '17,4902')]),
#  OrderedDict([('@ID', 'R01350'),
#               ('NumCode', '124'),
#               ('CharCode', 'CAD'),
#               ('Nominal', '1'),
#               ('Name', 'Канадский доллар'),
#               ('Value', '63,0529')]),
#  OrderedDict([('@ID', 'R01370'),
#               ('NumCode', '417'),
#               ('CharCode', 'KGS'),
#               ('Nominal', '100'),
#               ('Name', 'Киргизских сомов'),
#               ('Value', '98,7637')]),
#  OrderedDict([('@ID', 'R01375'),
#               ('NumCode', '156'),
#               ('CharCode', 'CNY'),
#               ('Nominal', '1'),
#               ('Name', 'Китайский юань'),
#               ('Value', '12,4818')]),
#  OrderedDict([('@ID', 'R01500'),
#               ('NumCode', '498'),
#               ('CharCode', 'MDL'),
#               ('Nominal', '10'),
#               ('Name', 'Молдавских леев'),
#               ('Value', '43,0487')]),
#  OrderedDict([('@ID', 'R01535'),
#               ('NumCode', '578'),
#               ('CharCode', 'NOK'),
#               ('Nominal', '10'),
#               ('Name', 'Норвежских крон'),
#               ('Value', '89,8870')]),
#  OrderedDict([('@ID', 'R01565'),
#               ('NumCode', '985'),
#               ('CharCode', 'PLN'),
#               ('Nominal', '1'),
#               ('Name', 'Польский злотый'),
#               ('Value', '18,5920')]),
#  OrderedDict([('@ID', 'R01585F'),
#               ('NumCode', '946'),
#               ('CharCode', 'RON'),
#               ('Nominal', '1'),
#               ('Name', 'Румынский лей'),
#               ('Value', '17,3520')]),
#  OrderedDict([('@ID', 'R01589'),
#               ('NumCode', '960'),
#               ('CharCode', 'XDR'),
#               ('Nominal', '1'),
#               ('Name', 'СДР (специальные права заимствования)'),
#               ('Value', '108,5644')]),
#  OrderedDict([('@ID', 'R01625'),
#               ('NumCode', '702'),
#               ('CharCode', 'SGD'),
#               ('Nominal', '1'),
#               ('Name', 'Сингапурский доллар'),
#               ('Value', '58,4470')]),
#  OrderedDict([('@ID', 'R01670'),
#               ('NumCode', '972'),
#               ('CharCode', 'TJS'),
#               ('Nominal', '10'),
#               ('Name', 'Таджикских сомони'),
#               ('Value', '63,5242')]),
#  OrderedDict([('@ID', 'R01700J'),
#               ('NumCode', '949'),
#               ('CharCode', 'TRY'),
#               ('Nominal', '10'),
#               ('Name', 'Турецких лир'),
#               ('Value', '54,2774')]),
#  OrderedDict([('@ID', 'R01710A'),
#               ('NumCode', '934'),
#               ('CharCode', 'TMT'),
#               ('Nominal', '1'),
#               ('Name', 'Новый туркменский манат'),
#               ('Value', '22,7008')]),
#  OrderedDict([('@ID', 'R01717'),
#               ('NumCode', '860'),
#               ('CharCode', 'UZS'),
#               ('Nominal', '10000'),
#               ('Name', 'Узбекских сумов'),
#               ('Value', '70,3159')]),
#  OrderedDict([('@ID', 'R01720'),
#               ('NumCode', '980'),
#               ('CharCode', 'UAH'),
#               ('Nominal', '10'),
#               ('Name', 'Украинских гривен'),
#               ('Value', '26,9005')]),
#  OrderedDict([('@ID', 'R01760'),
#               ('NumCode', '203'),
#               ('CharCode', 'CZK'),
#               ('Nominal', '10'),
#               ('Name', 'Чешских крон'),
#               ('Value', '35,3895')]),
#  OrderedDict([('@ID', 'R01770'),
#               ('NumCode', '752'),
#               ('CharCode', 'SEK'),
#               ('Nominal', '10'),
#               ('Name', 'Шведских крон'),
#               ('Value', '84,1404')]),
#  OrderedDict([('@ID', 'R01775'),
#               ('NumCode', '756'),
#               ('CharCode', 'CHF'),
#               ('Nominal', '1'),
#               ('Name', 'Швейцарский франк'),
#               ('Value', '84,9764')]),
#  OrderedDict([('@ID', 'R01810'),
#               ('NumCode', '710'),
#               ('CharCode', 'ZAR'),
#               ('Nominal', '10'),
#               ('Name', 'Южноафриканских рэндов'),
#               ('Value', '54,2404')]),
#  OrderedDict([('@ID', 'R01815'),
#               ('NumCode', '410'),
#               ('CharCode', 'KRW'),
#               ('Nominal', '1000'),
#               ('Name', 'Вон Республики Корея'),
#               ('Value', '64,3656')]),
#  OrderedDict([('@ID', 'R01820'),
#               ('NumCode', '392'),
#               ('CharCode', 'JPY'),
#               ('Nominal', '100'),
#               ('Name', 'Японских иен'),
#               ('Value', '62,7392')])]

# %%
my_array = []
for item in data['ValCurs']['Valute']:
    my_set = [item['CharCode'], item['Name'], item['Value']];
    my_array.append(my_set)
    print(my_set)
# Out:
# ['AUD', 'Австралийский доллар', '59,2560']
# ['AZN', 'Азербайджанский манат', '46,7370']
# ['GBP', 'Фунт стерлингов Соединенного королевства', '103,5907']
# ['AMD', 'Армянских драмов', '16,8565']
# ['BYN', 'Белорусский рубль', '28,2821']
# ['BGN', 'Болгарский лев', '44,1896']
# ['BRL', 'Бразильский реал', '16,8493']
# ['HUF', 'Венгерских форинтов', '23,0452']
# ['HKD', 'Гонконгский доллар', '10,1485']
# ['DKK', 'Датская крона', '11,5649']
# ['USD', 'Доллар США', '79,4529']
# ['EUR', 'Евро', '86,4289']
# ['INR', 'Индийских рупий', '10,4595']
# ['KZT', 'Казахстанских тенге', '17,4902']
# ['CAD', 'Канадский доллар', '63,0529']
# ['KGS', 'Киргизских сомов', '98,7637']
# ['CNY', 'Китайский юань', '12,4818']
# ['MDL', 'Молдавских леев', '43,0487']
# ['NOK', 'Норвежских крон', '89,8870']
# ['PLN', 'Польский злотый', '18,5920']
# ['RON', 'Румынский лей', '17,3520']
# ['XDR', 'СДР (специальные права заимствования)', '108,5644']
# ['SGD', 'Сингапурский доллар', '58,4470']
# ['TJS', 'Таджикских сомони', '63,5242']
# ['TRY', 'Турецких лир', '54,2774']
# ['TMT', 'Новый туркменский манат', '22,7008']
# ['UZS', 'Узбекских сумов', '70,3159']
# ['UAH', 'Украинских гривен', '26,9005']
# ['CZK', 'Чешских крон', '35,3895']
# ['SEK', 'Шведских крон', '84,1404']
# ['CHF', 'Швейцарский франк', '84,9764']
# ['ZAR', 'Южноафриканских рэндов', '54,2404']
# ['KRW', 'Вон Республики Корея', '64,3656']
# ['JPY', 'Японских иен', '62,7392']

# %%
my_array
# Out:
# [['AUD', 'Австралийский доллар', '59,2560'],
#  ['AZN', 'Азербайджанский манат', '46,7370'],
#  ['GBP', 'Фунт стерлингов Соединенного королевства', '103,5907'],
#  ['AMD', 'Армянских драмов', '16,8565'],
#  ['BYN', 'Белорусский рубль', '28,2821'],
#  ['BGN', 'Болгарский лев', '44,1896'],
#  ['BRL', 'Бразильский реал', '16,8493'],
#  ['HUF', 'Венгерских форинтов', '23,0452'],
#  ['HKD', 'Гонконгский доллар', '10,1485'],
#  ['DKK', 'Датская крона', '11,5649'],
#  ['USD', 'Доллар США', '79,4529'],
#  ['EUR', 'Евро', '86,4289'],
#  ['INR', 'Индийских рупий', '10,4595'],
#  ['KZT', 'Казахстанских тенге', '17,4902'],
#  ['CAD', 'Канадский доллар', '63,0529'],
#  ['KGS', 'Киргизских сомов', '98,7637'],
#  ['CNY', 'Китайский юань', '12,4818'],
#  ['MDL', 'Молдавских леев', '43,0487'],
#  ['NOK', 'Норвежских крон', '89,8870'],
#  ['PLN', 'Польский злотый', '18,5920'],
#  ['RON', 'Румынский лей', '17,3520'],
#  ['XDR', 'СДР (специальные права заимствования)', '108,5644'],
#  ['SGD', 'Сингапурский доллар', '58,4470'],
#  ['TJS', 'Таджикских сомони', '63,5242'],
#  ['TRY', 'Турецких лир', '54,2774'],
#  ['TMT', 'Новый туркменский манат', '22,7008'],
#  ['UZS', 'Узбекских сумов', '70,3159'],
#  ['UAH', 'Украинских гривен', '26,9005'],
#  ['CZK', 'Чешских крон', '35,3895'],
#  ['SEK', 'Шведских крон', '84,1404'],
#  ['CHF', 'Швейцарский франк', '84,9764'],
#  ['ZAR', 'Южноафриканских рэндов', '54,2404'],
#  ['KRW', 'Вон Республики Корея', '64,3656'],
#  ['JPY', 'Японских иен', '62,7392']]
